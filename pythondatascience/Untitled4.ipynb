# %% [markdown]
# <a href="https://colab.research.google.com/github/maulshreegarg/maulshreegarg/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
x=[1,2,3,4,5]
y=[5,3,2,1,3]
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
from matplotlib import pyplot as plt
a=np.arange(0,8,2)
b=np.arange(50,250,50)
plt.plot(a,b)
plt.title("a vs b")
plt.xlabel("a")
plt.ylabel("b")
# Out:
# Text(0, 0.5, 'b')

# %%
import numpy as np
from matplotlib import pyplot as plt
a=np.arange(0,8,2)
b=np.arange(50,250,50)
c=np.arange(0,4,1)
import matplotlib.pyplot as plt

plt.plot(a,b)
plt.plot(a,c)
plt.legend(["1","2"],loc="upper left")
plt.title("a vs b and c")
plt.xlabel("a")
plt.show()
plt.ylabel("b c")
# Out:
# Text(0, 0.5, 'b c')

# %%
a=np.array([1,2,3,4,5])
b=np.array([3,4,5,6,8])
c=np.array([4,7,9,11,16])
from matplotlib import pyplot as plt
plt.plot(a,b,marker="o")
plt.plot(a,c,marker="*")
plt.legend(["line 1","line 2"],loc="upper right")
plt.title("title")
plt.show()

# %%
plt.scatter(a,b)
plt.grid(axis="both")
plt.show()

# %%
plt.scatter(a,b,s=c,marker="^")
plt.colorbar()
plt.grid(axis="both")
plt.show()

# %%
plt.bar(a,b,color="g")
plt.grid(axis="both")
plt.show()

# %%
plt.barh(a,b,color="g",height=0.2)
plt.grid(axis="both")
plt.show()

# %%
# Data for the pie chart
labels = ['Geeks 1', 'Geeks 2', 'Geeks 3']
sizes = [35, 35, 30]
# Plotting the pie chart
plt.pie(sizes, labels=labels)
plt.title('Pie Chart Example')
plt.show()

# %%
Import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y1, y2 = [10, 20, 15, 25, 30], [5, 15, 10, 20, 25]
# Area Chart
plt.fill_between(x, y1, y2, color='skyblue', alpha=0.4, label='Area 1-2')
plt.plot(x, y1, label='Line 1', marker='o')
plt.plot(x, y2, label='Line 2', marker='o')
# Labels and Title
plt.xlabel('X-axis'), plt.ylabel('Y-axis'), plt.title('Area Chart Example')
# Legend and Display
plt.legend(), plt.show()

# %%
year = [1972, 1982, 1992, 2002, 2012]
e_india = [100.6, 158.61, 305.54, 394.96, 724.79]
e_bangladesh = [10.5, 25.21, 58.65, 119.27, 274.87]

plt.plot(year,e_india,color="r",label="india")
plt.plot(year,e_bangladesh,color="b",label="bd")
plt.legend(["india","bd"],loc="lower left")
plt.xlabel("year")
plt.ylabel("population")
plt.title("compare")
plt.show()

# %%
year = [1972, 1982, 1992, 2002, 2012]
e_india = [100.6, 158.61, 305.54, 394.96, 724.79]
e_bangladesh = [10.5, 25.21, 58.65, 119.27, 274.87]

plt.plot(year,e_india,color="r",label="india",marker="o")
plt.plot(year,e_bangladesh,color="b",label="bd",marker="*",linestyle="dashed")
plt.legend(["india","bd"],loc="lower left")
plt.xlabel("year")
plt.ylabel("population")
plt.title("compare")
plt.show()

# %%
a=[2,4,5,7,8,3]
plt.hist(a)
# Out:
# (array([1., 1., 0., 1., 0., 1., 0., 0., 1., 1.]),
#  array([2. , 2.6, 3.2, 3.8, 4.4, 5. , 5.6, 6.2, 6.8, 7.4, 8. ]),
#  <BarContainer object of 10 artists>)

# %%
# importing packages
import numpy as np
import matplotlib.pyplot as plt

# create data
x=np.array([1, 2, 3, 4, 5])

# making subplots
fig, ax = plt.subplots(2, 2)

# set data with subplots and plot
ax[0, 0].plot(x, x)
ax[0, 1].plot(x, x*2)
ax[1, 0].plot(x, x*x)
ax[1, 1].plot(x, x*x*x)

# set the title to subplots
ax[0, 0].set_title("Linear")
ax[0, 1].set_title("Double")
ax[1, 0].set_title("Square")
ax[1, 1].set_title("Cube")

# set spacing

plt.show()
